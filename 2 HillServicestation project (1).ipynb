# %%
class HillServiceCenter:
    
    def ServiceCenter(self):
        print("\t\t\t\t HillServiceCenter")
        print("\t\t\t\t Since 2005")
        print("\t\t\t\t www.HillService.com")
        print("\n\n\t\t\t\t SERVICELIST")
    
    def Service(self):
        A = ["Bike", "scooty", "Car", "Atv"]
        for L in A:
            print("\n\n", L)
        
        A = input("Enter the type of vehicle: ")
        if A == "Bike":
            self.Bike()
        elif A == "Car":
            self.Car()
        elif A == "Atv":
            self.Atv()
        elif A == "scooty":
            self.scooty()
        else:
            print("Wrong option: \nPlease choose the right option again.")
    
    def scooty(self):
        services = ["Engine oil: Check the engine oil level", "Tires: Check the tires", "Brakes: Check the brakes", "Battery: Maintain the battery", "Lights: Check lights", "Spark plug", "Cleaning"]
        prices = [100, 150, 500, 300, 200, 150, 400]
        scooty = {"scooty service type":services,"price":prices}
        import pandas as pd
        df = pd.DataFrame(scooty)
        print("\n\nScooty Service List\n\n")
        print(df)
        
        M=[]
        while True:
            posi = int(input("Enter the service position: "))
            p=scooty["price"] [posi]
            Total_price=p*posi
            M.append(Total_price)
            choice = input("Do you want another service (yes/no): ")
            if(choice=="no"):
                print("Thanks for visit")
                break
        s=sum(M)
        l=sum(M)*2
        k=s+l
        print("Labour charge = 10%")
        print("Total Amount:",s, "Rupees")
        print("Total Amount Including Labour charge:",k, "Rupees")
    
    def Bike(self):
        services = ["Air Filter", "Brakes", "Tire", "Chain", "Changing engine oil", "Brakes cleaning", "Fuel system", "Spark plug", "Battery maintenance"]
        prices = [100, 300, 2500, 900, 400, 200, 560, 350, 280]
        Bike = {"Bike service type":services,"price":prices}

        import pandas as pd
        df = pd.DataFrame(Bike)
        print("\nBike Service List\n")
        print(df)
        
        M=[]
        while True:
            posi = int(input("Enter the service position: "))
            p=Bike["price"] [posi]
            Total_price=p*posi
            M.append(Total_price)
            choice = input("Do you want another service (yes/no): ")
            if (choice=="no"):
                break
        s=sum(M)
        l=sum(M)*2
        k=s+l
        print("Labour charge = 10%")
        print("Total Amount:",s, "Rupees")
        print("Total Amount Including Labour charge:",k, "Rupees")

    def Car(self):
        services = ["Air Filter", "Coolant", "Spark plug", "Wiper blades", "Tires", "Transmission fluid", "Battery", "Car lights", "Engine oil"]
        prices = [2500, 900, 400, 600, 20000, 700, 2500, 5000, 2500]
        Car = {"Car service type":services,"price":prices}
        
        import pandas as pd
        df = pd.DataFrame(Car)
        print("\nCar Service List\n")
        print(df)
        
        M=[]
        while True:
            posi = int(input("Enter the service position: "))
            p=Car["price"][posi]
            Total_price=p*posi
            choice = input("Do you want another service (yes/no): ")
            if (choice=="no"):
                break
        s=sum(M)
        l=sum(M)*2
        k=s+l
        print("Labour charge = 20%")
        print("Total Amount:",s, "Rupees")
        print("Total Amount Including Labour charge:",k, "Rupees")
    
    def Atv(self):
        services = ["Tyre change", "Light change", "Brakes", "Engine oil", "Chain lube", "Battery"]
        prices = [5000, 1500, 600, 500, 200, 2000]
        atv = {"Atv service type":services, "price":prices}
        import pandas as pd
        df = pd.DataFrame(atv)
        print("\nATV Service List\n")
        print(df)
        
        M=[]
        while True:
            posi = int(input("Enter the service position: "))
            p=atv["price"][posi]
            Total_price=p*posi
            M.append(Total_price)
            choice = input("Do you want another service (yes/no): ")
            if (choice=="no"):
                break
        s=sum(M)
        l=sum(M)*2
        k=s+l
        print("Labour charge = 15%")
        print("Total Amount:",s, "Rupees")
        print("Total Amount Including Labour charge:",k,"Rupees")


obj = HillServiceCenter()
obj.ServiceCenter()
obj.Service()
# Out:
# 				 HillServiceCenter
# 				 Since 2005
# 				 www.HillService.com
#
#
# 				 SERVICELIST
#
#
#  Bike
#
#
#  scooty
#
#
#  Car
#
#
#  Atv
# Enter the type of vehicle:  scooty
# Scooty Service List
#
#
#                       scooty service type  price
# 0  Engine oil: Check the engine oil level    100
# 1                  Tires: Check the tires    150
# 2                Brakes: Check the brakes    500
# 3           Battery: Maintain the battery    300
# 4                    Lights: Check lights    200
# 5                              Spark plug    150
# 6                                Cleaning    400
# Enter the service position:  1
# Do you want another service (yes/no):  yes
# Enter the service position:  2
# Do you want another service (yes/no):  yes
# Enter the service position:  4
# Do you want another service (yes/no):  yes
# Enter the service position:  5
# Do you want another service (yes/no):  no
# Thanks for visit
# Labour charge = 10%
# Total Amount: 2700 Rupees
# ...
